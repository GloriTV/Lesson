# %% [markdown]
# ### Задание 5.6
# На текстильной фабрике есть 750 метров хлопка и 1000 метров полиэстера.
#
# Для изготовления свитшота требуется 1 метр хлопка и 2 метра полиэстера, для изготовления рубашки — 1.5 метра хлопка и 1 метр полиэстера.
#
# Свитшот можно продать за 30 евро, а рубашку — за 24 евро.
#
# Какое суммарное количество свитшотов и рубашек максимизирует возможную прибыль?

# %%
import numpy as np

a=np.array([750,1000]) # 750 метров хлопка и 1000 метров полиэстера
s=np.array([1, 2])
r=np.array([1.5, 1])

x=0
y=0
for i in range(750):
    for j in range(1000):
        temp=a-s*i-r*j
        if x<i*30+j*24 and temp[0]>-1 and temp[1]>-1:
            x=i*30+j*24
            y=i+j
   
print(y)
# Out:
# 625

# %%
# importing the required module
import matplotlib.pyplot as plt

# x axis values
x1 = [0,500]
# corresponding y axis values
y1 = [750,0]

# plotting the points 
plt.plot(x1, y1, label = "line 1")

# x axis values
x2 = [0,1000]
# corresponding y axis values
y2 = [500,0]

# plotting the points 
plt.plot(x2, y2, label = "line 2")


x3=[0,250]
y3=[375,375]
# plotting the points 
plt.plot(x3, y3, label='375', linestyle='dashed')

x4=[250,250]
y4=[0,375]
# plotting the points 
plt.plot(x4, y4, label='250', linestyle='dashed')

# naming the x axis
plt.xlabel('x - axis')
# naming the y axis
plt.ylabel('y - axis')

# giving a title to my graph
plt.title('My first graph!')

# function to show the plot
plt.show()

# %%
# for i in range(10):
#     for j in range(i):
#         print('*',end='')
#     print()
j=20    
for i in range(j):
    a=list('*'*(i*2-1))
    if i>3 :  a[np.random.randint(1,i)]='o'
    if i>9 :  a[np.random.randint(1,i)]='+'
    if i>15 :  a[np.random.randint(1,i)]='$'
    print(' '*(j-i),''.join(a))

for i in range(3):    
    print(' '*j,'|')
    
print( ' '*(j-3),'-------')
# Out:
#
#                     *
#                    ***
#                   *****
#                  *o*****
#                 **o******
#                *****o*****
#               ****o********
#              ****o**********
#             ******o**********
#            *+*o***************
#           **+*o****************
#          *o+********************
#         *o**+********************
#        ***+**o********************
#       *******+*****o***************
#      *********+****$****************
#     *o*+*******$*********************
#    ***$**o*********+******************
#   *******$***o+************************
#                      |
#                      |
#                      |
#                   -------

# %% [markdown]
# <table>
#     <thead>
#         <tr>
#             <th>Column 1</th>
#             <th>Column 2</th>
#             <th>Column 3</th>
#         </tr>
#     </thead>
#     <tbody>
#         <tr>
#             <td rowspan=4 align="center">R1 Text</td>
#             <td rowspan=2 align="center">R2 Text A</td>
#             <td align="center">R3 Text A</td>
#         </tr>
#         <tr>
#             <td align="center">R3 Text B</td>
#         </tr>
#         <tr>
#             <td rowspan=2 align="center">R2 Text B</td>
#             <td align="center">R3 Text C</td>
#         </tr>
#         <tr>
#             <td align="center">R3 Text D</td>
#         </tr>
#     </tbody>
# </table>
