# %%
import pandas as pd

# %%
solar_data = pd.read_csv('data/solarpower.csv')
solar_data.head()
# Out:
#          date  cum_power
# 0  2017-01-01    20111.0
# 1  2017-01-02    20112.0
# 2  2017-01-03    20115.0
# 3  2017-01-04    20117.0
# 4  2017-01-05    20119.0

# %%
solar_data['date']=pd.to_datetime(solar_data['date'])
solar_data['date']
# Out:
# 0     2017-01-01
# 1     2017-01-02
# 2     2017-01-03
# 3     2017-01-04
# 4     2017-01-05
#          ...
# 659   2018-10-22
# 660   2018-10-23
# 661   2018-10-24
# 662   2018-10-25
# 663   2018-10-26
# Name: date, Length: 664, dtype: datetime64[ns]

# %%
list_error=list(solar_data[solar_data['cum_power']==-1].index)
for ind in list_error:
    solar_data.loc[ind,['cum_power']]=(solar_data.loc[ind+1,['cum_power']]+solar_data.loc[ind-1,['cum_power']])/2

# %%
round(solar_data['cum_power'].mean())
# Out:
# 23848

# %%
solar_data['day_power'] = solar_data['cum_power']. diff ()

de

solar_data['yeg_m']=solar_data['date'].dt.to_period('M')
temp=round(solar_data.groupby('yeg_m',as_index=False)['day_power'].mean())

temp

import plotly.express as px
# temp.index
fig=px.line(
    solar_data,
    x='yeg_m',
    y='day_power',
)

fig.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[82], line 16
#       9 # temp.index
#      10 fig=px.line(
#      11     solar_data,
#      12     x='yeg_m',
#      13     y='day_power',
#      14 )
# ---> 16 fig.show()
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\plotly\basedatatypes.py:3410, in BaseFigure.show(self, *args, **kwargs)
#    3377 """
#    3378 Show a figure using either the default renderer(s) or the renderer(s)
#    3379 specified by the renderer argument
#    (...)
#    3406 None
#    3407 """
#    3408 import plotly.io as pio
# -> 3410 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\plotly\io\_renderers.py:386, in show(fig, renderer, validate, **kwargs)
#     383 fig_dict = validate_coerce_fig_to_dict(fig, validate)
#     385 # Mimetype renderers
# --> 386 bundle = renderers._build_mime_bundle(fig_dict, renderers_string=renderer, **kwargs)
#     387 if bundle:
#     388     if not ipython_display:
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\plotly\io\_renderers.py:294, in RenderersConfig._build_mime_bundle(self, fig_dict, renderers_string, **kwargs)
#     291             if hasattr(renderer, k):
#     292                 setattr(renderer, k, v)
# --> 294         bundle.update(renderer.to_mimebundle(fig_dict))
#     296 return bundle
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\plotly\io\_base_renderers.py:94, in PlotlyRenderer.to_mimebundle(self, fig_dict)
#      90 if config:
#      91     fig_dict["config"] = config
#      93 json_compatible_fig_dict = json.loads(
# ---> 94     to_json(fig_dict, validate=False, remove_uids=False)
#      95 )
#      97 return {"application/vnd.plotly.v1+json": json_compatible_fig_dict}
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\plotly\io\_json.py:221, in to_json(fig, validate, pretty, remove_uids, engine)
#     218     for trace in fig_dict.get("data", []):
#     219         trace.pop("uid", None)
# --> 221 return to_json_plotly(fig_dict, pretty=pretty, engine=engine)
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\plotly\io\_json.py:142, in to_json_plotly(plotly_object, pretty, engine)
#     137         opts["separators"] = (",", ":")
#     139     from _plotly_utils.utils import PlotlyJSONEncoder
#     141     return _safe(
# --> 142         json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts), _swap_json
#     143     )
#     144 elif engine == "orjson":
#     145     JsonConfig.validate_orjson()
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\json\__init__.py:234, in dumps(obj, skipkeys, ensure_ascii, check_circular, allow_nan, cls, indent, separators, default, sort_keys, **kw)
#     232 if cls is None:
#     233     cls = JSONEncoder
# --> 234 return cls(
#     235     skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236     check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#     237     separators=separators, default=default, sort_keys=sort_keys,
#     238     **kw).encode(obj)
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\_plotly_utils\utils.py:56, in PlotlyJSONEncoder.encode(self, o)
#      49 """
#      50 Load and then dump the result using parse_constant kwarg
#      51
#      52 Note that setting invalid separators will cause a failure at this step.
#      53
#      54 """
#      55 # this will raise errors in a normal-expected way
# ---> 56 encoded_o = super(PlotlyJSONEncoder, self).encode(o)
#      57 # Brute force guessing whether NaN or Infinity values are in the string
#      58 # We catch false positive cases (e.g. strings such as titles, labels etc.)
#      59 # but this is ok since the intention is to skip the decoding / reencoding
#      60 # step when it's completely safe
#      62 if not ("NaN" in encoded_o or "Infinity" in encoded_o):
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\json\encoder.py:199, in JSONEncoder.encode(self, o)
#     195         return encode_basestring(o)
#     196 # This doesn't pass the iterator directly to ''.join() because the
#     197 # exceptions aren't as detailed.  The list call should be roughly
#     198 # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199 chunks = self.iterencode(o, _one_shot=True)
#     200 if not isinstance(chunks, (list, tuple)):
#     201     chunks = list(chunks)
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\json\encoder.py:257, in JSONEncoder.iterencode(self, o, _one_shot)
#     252 else:
#     253     _iterencode = _make_iterencode(
#     254         markers, self.default, _encoder, self.indent, floatstr,
#     255         self.key_separator, self.item_separator, self.sort_keys,
#     256         self.skipkeys, _one_shot)
# --> 257 return _iterencode(o, 0)
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\site-packages\_plotly_utils\utils.py:133, in PlotlyJSONEncoder.default(self, obj)
#     131     except NotEncodable:
#     132         pass
# --> 133 return _json.JSONEncoder.default(self, obj)
#
# File c:\Users\Temnykov\AppData\Local\Programs\Python\Python38\lib\json\encoder.py:179, in JSONEncoder.default(self, o)
#     160 def default(self, o):
#     161     """Implement this method in a subclass such that it returns
#     162     a serializable object for ``o``, or calls the base implementation
#     163     (to raise a ``TypeError``).
#    (...)
#     177
#     178     """
# --> 179     raise TypeError(f'Object of type {o.__class__.__name__} '
#     180                     f'is not JSON serializable')
#
# TypeError: Object of type Period is not JSON serializable
