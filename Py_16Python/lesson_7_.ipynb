# %%
# Импортируем модуль pandas
import pandas as pd 

diabetes = pd.read_csv('data/recipes.csv')
display(diabetes.head())
diabetes.tail()
# Out:
#       id      cuisine  ingredients  slaw mix  jalapeno chilies  \
# 0  10259        greek            9     False             False
# 1  25693  southern_us           11     False             False
# 2  20130     filipino           12     False             False
# 3  22213       indian            4     False             False
# 4  13162       indian           20     False             False
#
#    fresh tarragon  roasted garlic  powdered sugar  cream of chicken soup  \
# 0           False           False           False                  False
# 1           False           False           False                  False
# 2           False           False           False                  False
# 3           False           False           False                  False
# 4           False           False           False                  False
#
#    peaches  ...  hot chili  pizza crust  onions  pimentos  organic sugar  \
# ...
