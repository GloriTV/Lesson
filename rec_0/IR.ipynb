# %% [markdown]
# Находим отличие от первог а затем и второго списка

# %%
list_a = [8900,4400, 600,500, 600,450, 600,550, 600,1600, 600,500, 600,450, 650,500, 600,450, 650,1600, 600,1600, 600,1600, 600,500, 600,1600, 650,1550, 650,1550, 650,1600, 600,500, 600,450,  650,1550, 600,550, 600,1600,600,500, 600,450, 650,450, 650,1600, 600,1600, 600,500, 600,1600, 600,500, 650,1550, 650,1550, 650,1550, 650]
list_b = [8900,4400, 600,500, 600,450, 650,450, 600,1650, 600,500, 600,500, 600,500, 600,450, 600,1650, 600,1600, 600,1600, 600,500, 600,1600, 600,1600, 650,1600, 600,1600, 600,1600,600,1600, 600,500,  600,1600,600,500, 600,500, 600,500, 600,500, 600,500, 600,500, 600,1600, 600,500, 600,1600, 600,1600, 600,1600, 600,1650, 600]
list_c = [8900,4350, 600,500, 650,450, 600,500, 600,500,  600,500, 600,500, 600,1600,600,500, 600,1600, 600,1600, 650,1550, 650,1600,600,1550, 650,1600, 600,500,  600,450,  650,500, 600,1600, 600,500,  600,450, 650,500, 600,450, 650,1600, 600,500, 600,1600, 600,500, 600,1600, 600,1600, 650,1550, 650,1600, 600,450, 650,1550, 650]
text=''
text1=''
if len(list_a)==len(list_b) and len(list_a)==len(list_c):
    for i in range(len(list_a)):
        if list_a[i] != list_b[i]:
            text +=f'KEY[{i}] = {list_b[i]}; '
        if (list_a[i] != list_b[i]) or (list_a[i] != list_c[i]):
            text1 +=f'KEY[{i}] = {list_c[i]}; '     
    print(text) 
    print()
    print(text1)
    
else: 
    print('Error len')
# Out:
# KEY[6] = 650; KEY[7] = 450; KEY[9] = 1650; KEY[13] = 500; KEY[14] = 600; KEY[18] = 600; KEY[19] = 1650; KEY[28] = 600; KEY[29] = 1600; KEY[31] = 1600; KEY[32] = 600; KEY[35] = 1600; KEY[37] = 1600; KEY[38] = 600; KEY[39] = 500; KEY[41] = 1600; KEY[43] = 500; KEY[47] = 500; KEY[48] = 600; KEY[49] = 500; KEY[50] = 600; KEY[51] = 500; KEY[53] = 500; KEY[55] = 1600; KEY[57] = 500; KEY[59] = 1600; KEY[60] = 600; KEY[61] = 1600; KEY[62] = 600; KEY[63] = 1600; KEY[64] = 600; KEY[65] = 1650; KEY[66] = 600;
#
# ...
