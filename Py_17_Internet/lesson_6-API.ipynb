# %%
from bs4 import BeautifulSoup # Импортируем библиотеку BeautifulSoup
import requests # Импортируем библиотеку requests
import pandas as pd 
import os
# !pip install opencv-python
from dotenv import load_dotenv

# %%
load_dotenv()
token = os.getenv('token')
url = 'https://api.vk.com/method/users.get?user_id=1&v=5.95&access_token='

response = requests.get(url+token) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
# page = BeautifulSoup(response.text, 'html.parser') # Создаём объект BeautifulSoup, указывая html-парсер

# %%
print(response) # Выводим значение response на экран как объект

print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# <Response [200]>
# {"response":[{"id":1,"first_name":"Pavel","last_name":"Durov","can_access_closed":true,"is_closed":false}]}

# %%
url='https://api.vk.com/method/users.get?user_id=1&v=5.95&fields=sex,bdate&access_token='
response = requests.get(url+token) # Выполняем GET-запрос, содержимое ответа присваивается переменной response
print(response) # Выводим значение response на экран как объект
print(response.text) # Выводим содержимое атрибута text переменной response на экран
# Out:
# <Response [200]>
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Pavel","last_name":"Durov","can_access_closed":true,"is_closed":false}]}

# %%
url = 'https://api.vk.com/method/users.get' # Указываем адрес страницы к которой делаем запрос
params = {'user_id': 1, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Перечисляем параметры нашего запроса в словаре params
response = requests.get(url, params=params) # Отправляем запрос
print(response.text) # Выводим текст ответа на экран
# Out:
# {"response":[{"id":1,"bdate":"10.10.1984","sex":2,"first_name":"Павел","last_name":"Дуров","can_access_closed":true,"is_closed":false}]}

# %%
from pprint import pprint # Импортируем функцию pprint()
pprint(response.json()) # Выводим содержимое словаря, содержащего ответ, на экран
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров',
#                'sex': 2}]}

# %%
user = response.json()['response'][0] # Извлекаем из словаря по ключу response информацию о первом пользователе
print(user['bdate']) # Выводим дату рождения первого пользователя на экран
# Out:
# 10.10.1984

# %% [markdown]
# 6.1

# %%
print(user['first_name'])
# Out:
# Павел

# %%
ids = ",".join(map(str, range(1, 4))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
pprint(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()
# Out:
# {'response': [{'bdate': '10.10.1984',
#                'can_access_closed': True,
#                'first_name': 'Павел',
#                'id': 1,
#                'is_closed': False,
#                'last_name': 'Дуров'},
#               {'bdate': '14.2',
#                'can_access_closed': False,
#                'first_name': 'Александра',
#                'id': 2,
#                'is_closed': True,
#                'last_name': 'Владимирова'},
#               {'can_access_closed': True,
#                'deactivated': 'deleted',
#                'first_name': 'DELETED',
#                'id': 3,
#                'is_closed': False,
#                'last_name': ''}]}

# %% [markdown]
# 6.2

# %%
ids = ",".join(map(str, range(1, 501))) # Формируем строку, содержащую информацию о поле id первых трёх пользователей
params = {'user_ids': ids, 'v': 5.95, 'fields': 'sex,bdate', 'access_token': token, 'lang': 'ru'} # Формируем строку параметров
user=(requests.get(url, params=params).json()) # Посылаем запрос, полученный ответ в формате JSON-строки преобразуем в словарь и выводим на экран его содержимое, используя функцию pprint()

# %%
# Создаём объект DataFrame из списка recipes
df = pd.DataFrame(user['response']) 
# Выводим на экран первые строки полученного DataFrame

df_filter=df[df['sex']>0]['sex']
print('(sex=1):',(df_filter.value_counts(True)).round(2)[1])
# Out:
# (sex=1): 0.49

# %%
x=0
y=0
for i in user['response']:
    if i['sex']==2: x+=1
    if i['sex']==1: y+=1
    
print('(sex=1):',round(1/(x+y)*y,2))
# Out:
# (sex=1): 0.49

# %%
# import requests # Импортируем модуль requests
# token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
params = {'group_id': 'vk', 'v': 5.95, 'access_token': token} # Формируем строку параметров
response = requests.get(url, params = params) # Посылаем запрос
data = response.json() # Ответ сохраняем в переменной data в формате словаря
print(data) # Выводим содержимое переменной data на экран (отображён фрагмент)
# Out:
# {'response': {'count': 13454803, 'items': [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 431, 450, 467, 485, 510, 550, 619, 640, 690, 702, 721, 804, 809, 831, 832, 834, 847, 900, 905, 907, 914, 930, 943, 952, 958, 966, 976, 979, 997, 1000, 1018, 1023, 1032, 1033, 1038, 1039, 1059, 1097, 1131, 1139, 1140, 1159, 1174, 1185, 1188, 1301, 1333, 1334, 1351, 1381, 1386, 1388, 1406, 1411, 1418, 1432, 1494, 1503, 1531, 1550, 1568, 1586, 1590, 1593, 1598, 1610, 1615, 1632, 1634, 1650, 1679, 1690, 1697, 1698, 1699, 1700, 1721, 1740, 
, 10365, 10366, 10376, 10516, 10518, 10570, 10596, 10607, 10615, 10621, 10639, 10682, 10697, 10741, 10749, 10767, 10811, 10833, 10887, 10919, 10955, 10956, 10961, 10972, 10999, 11027, 11064, 11068, 11081, 11084, 11150, 11187, 11191, 11236, 11243, 11271, 11303, 11420, 11446, 11451, 11483, 11568, 11649, 11723, 11727, 11747, 11754, 11763, 11768, 11782, 11865, 11964, 11983, 12005, 12029, 12036, 12097, 12133, 12150, 12159, 12172, 12213, 12252, 12255, 12264, 12316, 12325, 12332, 12345, 12353, 12367, 12407, 12441, 12448, 12454, 12456, 12473, 12477, 12545, 12560, 12570, 12617, 12637, 12638, 12707, 12716, 12718, 12736, 12748, 12756, 12762, 12803, 12808, 12 ...

# %%
print(len(data['response']['items'])) # Выводим на экран количество элементов словаря
# Out:
# 1000

# %%
users_for_checking = data['response']['items'][:20] # Загружаем в переменную информацию об id первых 20 пользователей в виде списка
print(users_for_checking) # Выводим перечень id первых 20 пользователей
# Out:
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 431, 450, 467, 485, 510, 550]

# %%
# import requests # Импортируем модуль requests
# token = ' ... ' # Указываем свой сервисный токен
# url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес обращения
count = 5 
offset = 0 
user_ids = [] 
max_count = 20 
while offset < max_count: 
    # Будем выгружать по count=5 пользователей, 
    # начиная с того места, где закончили на предыдущей итерации (offset) 
    print('Выгружаю {} пользователей с offset = {}'.format(count, offset))   
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    # Увеличиваем смещение на количество строк, которое мы уже выгрузили 
    offset += count 
print(user_ids)
# Out:
# Выгружаю 5 пользователей с offset = 0
# Выгружаю 5 пользователей с offset = 5
# Выгружаю 5 пользователей с offset = 10
# Выгружаю 5 пользователей с offset = 15
# [6, 19, 47, 54, 79, 177, 198, 212, 219, 239, 243, 345, 407, 421, 431, 450, 467, 485, 510, 550]

# %%
print(user_ids == users_for_checking)
# Out:
# True

# %% [markdown]
# Воспользуемся библиотекой time и методом sleep, с помощью которого мы можем добавить паузу, например в 0.5 секунд, после каждого запроса:

# %%
# import requests # Импортируем модуль requests
import time # Импортируем модуль time
# token = ' ... ' # Указываем свой сервисный токен
# url = 'https://api.vk.com/method/groups.getMembers' # Указываем адрес страницы, к которой делаем запрос
count = 1000 
offset = 0  
user_ids = []  
while offset < 5000: 
    params = {'group_id': 'vk', 'v': 5.95, 'count': count, 'offset': offset, 'access_token': token} 
    response = requests.get(url, params = params) 
    data = response.json() 
    user_ids += data['response']['items'] 
    offset += count 
    print('Ожидаю 0.5 секунды...') 
    time.sleep(0.5) 
print('Цикл завершен, offset =',offset)
# Out:
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Ожидаю 0.5 секунды...
# Цикл завершен, offset = 5000

# %% [markdown]
# Для получения информации о сообщениях на стене в API ВКонтакте предусмотрен метод wall.get. Применим его:

# %%
# import requests # Импортируем модуль requests
# from pprint import pprint # Импортируем функцию pprint()
# token = ' ... ' # Указываем свой сервисный токен
url = 'https://api.vk.com/method/wall.get' # Указываем адрес страницы, к которой делаем запрос
params = {'domain': 'vk', 'filter': 'owner', 'count': 1000, 'offset': 0, 'access_token': token, 'v': 5.95} 
response = requests.get(url, params = params) 
pprint(response.json())
# Out:
# {'response': {'count': 689,
#               'items': [{'attachments': [],
#                          'comments': {'can_post': 1,
#                                       'count': 65,
#                                       'groups_can_post': True},
#                          'date': 1708344300,
#                          'from_id': -22822305,
#                          'hash': 'acq7bmTkX76qGV9p9A',
#                          'id': 1461279,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 94,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 9, 'user_reposted': 0},
#                          'text': 'А похвастайтесь своими результатами в '
#                                  '«Шагах»!\n'
#                                  '\n'
#                                  'С телефона заходим '
#                                  '[https://vk.com/app7539087_9849589|сюда], '
#                                  'делаем скриншот, скидываем в комментарии 👇',
#                          'type': 'post',
#                          'views': {'count': 32180}},
#                         {'attachments': [{'photo': {'access_key': '14c2361008f51686eb',
#                                                     'album_id': -7,
#                                                     'date': 1707996203,
#                                                     'id': 457346700,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1460705,
#                                                     'sizes': [{'height': 114,
#                                                                'type': 'm',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=130x114&quality=96&sign=5669913c6e989a7215dda6a0ec06e786&c_uniq_tag=EvcYpO2YWLNGcgpuAoYR-0dKBPzkopotM2vAAWW2dUk&type=album',
#                                                                'width': 130},
#                                                               {'height': 114,
#                                                                'type': 'o',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=130x114&quality=96&sign=5669913c6e989a7215dda6a0ec06e786&c_uniq_tag=EvcYpO2YWLNGcgpuAoYR-0dKBPzkopotM2vAAWW2dUk&type=album',
#                                                                'width': 130},
#                                                               {'height': 176,
#                                                                'type': 'p',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=200x176&quality=96&sign=d5607df50e66779512fc63776b12c980&c_uniq_tag=5nUC_5xZqA7rb_eztmQ3hXkZmzygGZI-MNMHeU4oY84&type=album',
#                                                                'width': 200},
#                                                               {'height': 281,
#                                                                'type': 'q',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=320x281&quality=96&sign=5e4ca1ffd7a9b93036c3e522206b612f&c_uniq_tag=xXx31fnCAoyjtqyinJho3caAeFSW0GTTjhYz5TFmkIQ&type=album',
#                                                                'width': 320},
#                                                               {'height': 448,
#                                                                'type': 'r',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=510x448&quality=96&sign=406d932859e6f8f3c1acd860d5bbfd9b&c_uniq_tag=jpf42OgZAoIaD-CzZYhXGmS-gJJEQWf_4zJKPkf0BTM&type=album',
#                                                                'width': 510},
#                                                               {'height': 66,
#                                                                'type': 's',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=75x66&quality=96&sign=5b283ea1700ad0e99abb5cb518127249&c_uniq_tag=NbUXOJyI1l6388hcO9NP7Rb_kaXcfx4-r1lQXa7HUQk&type=album',
#                                                                'width': 75},
#                                                               {'height': 1125,
#                                                                'type': 'w',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=1280x1125&quality=96&sign=8fbb48fcd994bc48a9a59ed20a1757ac&c_uniq_tag=gntQZXa4MBdM9CTzAuw_RPJhTCrXNpe0uX0XFF2XUSc&type=album',
#                                                                'width': 1280},
#                                                               {'height': 531,
#                                                                'type': 'x',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=604x531&quality=96&sign=a18333d3737519fc020f892e70db01f7&c_uniq_tag=55RD7kOaiNICmjCiDSmNROJKSOhCqnsac6QZfi2JyF8&type=album',
#                                                                'width': 604},
#                                                               {'height': 709,
#                                                                'type': 'y',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=807x709&quality=96&sign=7bcaf19377f0b713d2a2c9b47142961e&c_uniq_tag=yj-YRdzPVus9knEQiQIJVEye8SBdwjJUqtrxgiy_Sbg&type=album',
#                                                                'width': 807},
#                                                               {'height': 1125,
#                                                                'type': 'z',
#                                                                'url': 'https://sun51-2.userapi.com/impg/cFQBieOVR6Gttxmc9K9vo8yNoGIvLZbsAPmkeQ/NYLsWZa1oE4.jpg?size=1280x1125&quality=96&sign=8fbb48fcd994bc48a9a59ed20a1757ac&c_uniq_tag=gntQZXa4MBdM9CTzAuw_RPJhTCrXNpe0uX0XFF2XUSc&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '87389401c81e5ab5a9'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 349,
#                                       'groups_can_post': True},
#                          'date': 1707996601,
#                          'from_id': -22822305,
#                          'hash': 'ho9uoBR6hiUjgDbtew',
#                          'id': 1460705,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 351,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 70, 'user_reposted': 0},
#                          'text': 'ВКонтакте появился [vk.com/safety|Центр '
#                                  'цифрового комфорта].\n'
#                                  '\n'
#                                  'В нём собраны рекомендации по поддержке '
#                                  'ментального здоровья, советы по поведению в '
#                                  'сложных ситуациях и тематические новости. '
#                                  'Например, можно узнать, как '
#                                  'противодействовать вражде и травле, как '
#                                  'распознать злоумышленника и как работает '
#                                  'модерация ВКонтакте.\n'
#                                  '\n'
#                                  'Материалы мы готовили вместе с экспертами '
#                                  'благотворительного фонда '
#                                  '[https://vk.com/shalash.academy|«Шалаш»]. '
#                                  'Его сотрудники помогают детям, родителям и '
#                                  'учителям справляться с проявлениями '
#                                  'агрессии.\n'
#                                  '\n'
#                                  'В Центре цифрового комфорта будут регулярно '
#                                  'публиковаться свежие материалы. Найти его '
#                                  'можно под боковым меню во вкладке «Ещё», '
#                                  'если заходить ВКонтакте с компьютера, и по '
#                                  'прямой [vk.com/safety|ссылке] в приложении '
#                                  'для iOS и Android.',
#                          'type': 'post',
#                          'views': {'count': 178258}},
#                         {'attachments': [{'photo': {'access_key': 'f930969a6fca2e6430',
#                                                     'album_id': -7,
#                                                     'date': 1707908176,
#                                                     'id': 457346651,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1460426,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=130x130&quality=96&sign=44797a3ef821328546b92cb64e85b037&c_uniq_tag=dxQ_pe6qpxg0_okhXt8R35O1dpwXuLoD6hS_HlspQvg&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=130x130&quality=96&sign=44797a3ef821328546b92cb64e85b037&c_uniq_tag=dxQ_pe6qpxg0_okhXt8R35O1dpwXuLoD6hS_HlspQvg&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=200x200&quality=96&sign=2534f6fc2b3f4f9311af975a769169bc&c_uniq_tag=jyRouLUKHl-hV5PrBF2g_omIZfq0qnx8WmDf5KV3lRQ&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=320x320&quality=96&sign=8ef7800c0c58ecb1d61cf1ba29828a44&c_uniq_tag=txONf9QJ3A85JeaXGo5GjOHVLJZkzNBWSlphdVeXUsY&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=510x510&quality=96&sign=cbf5b4351a78fc99aa490dde3e8bc5c7&c_uniq_tag=X7IFoT1kl97gHPfjp21XW4lyuhBwS8DceL1AYLLlU4g&type=album',
#                                                                'width': 510},
#                                                               {'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=75x75&quality=96&sign=94eba2b474f4d7bfaabbde6a1a159a6e&c_uniq_tag=j_DBvqT41BzbhGeTXqf1yWj2tCLRFuAIQjLKUXVSINI&type=album',
#                                                                'width': 75},
#                                                               {'height': 1500,
#                                                                'type': 'w',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=1500x1500&quality=96&sign=2f525a9d7433198c9bf7b3689430d075&c_uniq_tag=22emjBUPkJULp4eS77ynrgBv8y7v6SR40uCg6fXSzjk&type=album',
#                                                                'width': 1500},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=604x604&quality=96&sign=8c03a23063dca976c1b26ca85d6d9f62&c_uniq_tag=N6kjsRdXFOIvdJW8VV2M-RACrOu1rLX0AfR09cNkk0I&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=807x807&quality=96&sign=c1f3f2772a3271f2e9537f8b923b1a0a&c_uniq_tag=Z5RI8UealwzXUxplYTVLSiFyLNFzAxixkRGLEISXFyE&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun51-2.userapi.com/impg/iKbP1u-i6QzgWg3y8AU-ZDqXtAyJ_lfUDi9xBg/d6k6YAmbJvc.jpg?size=1280x1280&quality=96&sign=80ad8e18d41c165933a117daf9e90151&c_uniq_tag=qCmGWCTouN3NdRejXy7cXfWoKXcE9k00RhetW-_RXUQ&type=album',
#                                                                'width': 1280}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': '4e43a7a96b7541937e'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 244,
#                                       'groups_can_post': True},
#                          'date': 1707908176,
#                          'from_id': -22822305,
#                          'hash': 'KlDqWpVNxUjI9xUSeg',
#                          'id': 1460426,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 412,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 39, 'user_reposted': 0},
#                          'text': 'Всех с Днём влюблённых! 💙\n'
#                                  '\n'
#                                  'Надеемся, вы проводите его вместе со своей '
#                                  'второй половинкой. А если второй половинки '
#                                  'пока нет, то загляните в '
#                                  '[https://vk.com/dating|VK Знакомства], она '
#                                  'наверняка там!\n'
#                                  '\n'
#                                  'Кстати, в VK Знакомствах появились '
#                                  'дополнительные отметки. Всем, кто их '
#                                  'установит, станут доступны премиум-функции в '
#                                  'подарок, а ещё с этими отметками можно '
#                                  'принять участие в розыгрыше свиданий на '
#                                  'катке в [https://vk.com/vkdating|сообществе] '
#                                  'VK Знакомств.\n'
#                                  '\n'
#                                  'И это не всё! Вот что ещё мы для вас '
#                                  'подготовили:\n'
#                                  '\n'
#                                  '💙VK Клипы проведут '
#                                  '[https://vk.com/video-194351072_456241811|прямую '
#                                  'трансляцию] с клипером Кариной Мурашкиной. В '
#                                  'течение часа ведущая будет делать '
#                                  'пользователям предсказания на коротких '
#                                  'роликах.\n'
#                                  '\n'
#                                  '💙 В «Шагах» появился вызов '
#                                  '[https://vk.com/steps#challengeAAAAAAAAAAAABXAPAEAAAAAAAA&ref=copy_link&ref_id=11143326&sharing_id=By4ffCW4ugXc|«Навстречу '
#                                  'любви»].\n'
#                                  '\n'
#                                  '💙 И не забываем про '
#                                  '[https://vk.com/app6851096|«Коробку для '
#                                  'валентинок»]! Отправьте кому-нибудь тёплое '
#                                  'пожелание. Быть может, симпатия окажется '
#                                  'взаимной, и это 14 февраля станет '
#                                  'по-настоящему особенным!',
#                          'type': 'post',
#                          'views': {'count': 195109}},
#                         {'attachments': [{'photo': {'access_key': '11402b7538f95710a4',
#                                                     'album_id': -7,
#                                                     'date': 1707490737,
#                                                     'id': 457346590,
#                                                     'owner_id': -22822305,
#                                                     'sizes': [{'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun51-1.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=130x130&quality=96&sign=7822c0a71e6783098e750959e82f3eae&c_uniq_tag=1oMLBZw_ewKuo6WcT7bBD75rQByypxMKA-goPoEpExI&type=album',
#                                                                'width': 130},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun51-1.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=130x130&quality=96&sign=7822c0a71e6783098e750959e82f3eae&c_uniq_tag=1oMLBZw_ewKuo6WcT7bBD75rQByypxMKA-goPoEpExI&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun51-1.userapi.com/impg/hkijg-fGyhQ7KfZHM9hZGWJWGgLmwsD8PNqsLw/V6ncES1Y2hI.jpg?size=200x200&quality=96&sign=e00fbde8ae8c4e548f49106697b1a591&c_uniq_tag=APct1WHvRfWxYyl5pijUO_g6wgVX70yvzUmux2yYtL8&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://s

#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 5995, 'user_reposted': 0},
#                          'text': 'Теперь в записях и комментариях можно '
#                                  'скрывать нецензурные выражения: их '
#                                  'автоматически заменит набор символов. Фильтр '
#                                  'включается в настройках профиля. С '
#                                  'сегодняшнего дня функция начнёт постепенно '
#                                  'становиться доступной всем пользователям. \n'
#                                  '\n'
#                                  'Всё это нужно, чтобы вы чувствовали себя '
#                                  'максимально комфортно и могли гибко '
#                                  'управлять своим цифровым пространством. '
#                                  'Ранее для этого мы уже запустили режим '
#                                  '«Личное пространство», который помогает '
#                                  'оградиться от нежелательного внимания, а '
#                                  'также начали предупреждать о подозрительных '
#                                  'собеседниках в VK Мессенджере.',
#                          'type': 'post',
#                          'views': {'count': 834521}},
#                         {'attachments': [{'photo': {'access_key': '20bee9d71d299b4508',
#                                                     'album_id': -7,
#                                                     'date': 1681804917,
#                                                     'id': 457341671,
#                                                     'owner_id': -22822305,
#                                                     'post_id': 1402353,
#                                                     'sizes': [{'height': 75,
#                                                                'type': 's',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=75x75&quality=95&sign=6683d690ddbfd84a7c8d5ed05a56295b&c_uniq_tag=hovrAWvWlJ9L-UN02wjUj2Avnptj81uKeBlBwl48XR4&type=album',
#                                                                'width': 75},
#                                                               {'height': 130,
#                                                                'type': 'm',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=130x130&quality=95&sign=e634c009e7d4d3682bc23ad1aa62e909&c_uniq_tag=lcOrVowSqtGMxdu4LLsMGxYaAyraO-VZp9hlF8cn-TU&type=album',
#                                                                'width': 130},
#                                                               {'height': 604,
#                                                                'type': 'x',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=604x604&quality=95&sign=6d3c92893b7bd284067a1e7c26c8aea9&c_uniq_tag=yohMKuJkrK0y_57vUvlduOypvXVxnmt4jY4O_kc6d6s&type=album',
#                                                                'width': 604},
#                                                               {'height': 807,
#                                                                'type': 'y',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=807x807&quality=95&sign=759ae1d7a6045c7d3ade189eb893a654&c_uniq_tag=xSivO1laMrU4sxIekZwbV9gZdjChG31wiiYmSYYeI5c&type=album',
#                                                                'width': 807},
#                                                               {'height': 1280,
#                                                                'type': 'z',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=1280x1280&quality=95&sign=80ed10ad679a1aa478e9ca08e363aa46&c_uniq_tag=oik5r9fDkY8jAMUBXUJVeKIj0v45b8ocjdQ1BckMT6I&type=album',
#                                                                'width': 1280},
#                                                               {'height': 1920,
#                                                                'type': 'w',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=1920x1920&quality=95&sign=0671bbe16d11a9aa01af80d29210f91d&c_uniq_tag=hnWaZckgXMKDnHH6lFx9w5D-FoVwodOwWdy2FGNQSXk&type=album',
#                                                                'width': 1920},
#                                                               {'height': 130,
#                                                                'type': 'o',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=130x130&quality=95&sign=e634c009e7d4d3682bc23ad1aa62e909&c_uniq_tag=lcOrVowSqtGMxdu4LLsMGxYaAyraO-VZp9hlF8cn-TU&type=album',
#                                                                'width': 130},
#                                                               {'height': 200,
#                                                                'type': 'p',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=200x200&quality=95&sign=6002c567dc4a221a9c83032aacb16a26&c_uniq_tag=rjve8pzhDMhBUj7yWBm97cWRdQbUiAZmUm24AyI7Ia8&type=album',
#                                                                'width': 200},
#                                                               {'height': 320,
#                                                                'type': 'q',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=320x320&quality=95&sign=935e2a3d7c19b177b4b83324f87b4be6&c_uniq_tag=iIPRRJmkOi84VIk76ZQ9-XKb-IXF0TMEFCSH13L_9uE&type=album',
#                                                                'width': 320},
#                                                               {'height': 510,
#                                                                'type': 'r',
#                                                                'url': 'https://sun51-1.userapi.com/impg/qSH6PPwoJA65rdFU_AlznCuQ3h8DDpTBfoDlBg/sf0ycNlGNow.jpg?size=510x510&quality=95&sign=9cbb7c8db906d80ff5f1d7223a8b3c68&c_uniq_tag=agyu5wZMecPNSYr7GAMmQvike6abvwHZ9rIGNXq2M-A&type=album',
#                                                                'width': 510}],
#                                                     'text': '',
#                                                     'user_id': 100,
#                                                     'web_view_token': 'c9ab3ba95145aa62dd'},
#                                           'type': 'photo'}],
#                          'comments': {'can_post': 1,
#                                       'count': 319,
#                                       'groups_can_post': True},
#                          'date': 1681804931,
#                          'from_id': -22822305,
#                          'hash': 'Es8ZEYPtblgye-sg0w',
#                          'id': 1402353,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 1010,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 2830, 'user_reposted': 0},
#                          'text': 'ВКонтакте проведёт продажу первой '
#                                  'собственной NFT-коллекции CryptoSpotty! Мы '
#                                  'создали 8\u202f000 уникальных токенов, '
#                                  'которые скоро каждый сможет купить в сервисе '
#                                  '[https://vk.com/vk_nft_hub#/home/drop|VK '
#                                  'NFT]. Все вырученные с продажи NFT деньги '
#                                  'направим на восстановление памятника '
#                                  'архитектуры и одного из самых известных '
#                                  'исторических зданий Санкт-Петербурга — '
#                                  'доходного дома Бака. Так цифровое искусство '
#                                  'поможет реальному. \n'
#                                  '\n'
#                                  'Главным героем коллекции стал пёсик-маскот '
#                                  'Спотти. После покупки NFT его можно будет '
#                                  'установить на аватар или загрузить на '
#                                  'витрину в профиле. Подробности — здесь: '
#                                  'vk.com/press/nft-spotty.',
#                          'type': 'post',
#                          'views': {'count': 723483}},
#                         {'attachments': [{'type': 'video',
#                                           'video': {'access_key': '1d72c6f70d79d04170',
#                                                     'can_add': 1,
#                                                     'can_add_to_faves': 0,
#                                                     'can_dislike': 1,
#                                                     'can_like': 1,
#                                                     'can_repost': 1,
#                                                     'can_subscribe': 1,
#                                                     'comments': 0,
#                                                     'date': 1681477827,
#                                                     'description': '',
#                                                     'duration': 25,
#                                                     'first_frame_1280': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=0&type=39&tkn=7WP6TVLi-_pCbdedCvOHmBCL-WU&fn=vid_w',
#                                                     'first_frame_130': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=0&type=39&tkn=7WP6TVLi-_pCbdedCvOHmBCL-WU&fn=vid_sm',
#                                                     'first_frame_160': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=0&type=39&tkn=7WP6TVLi-_pCbdedCvOHmBCL-WU&fn=vid_d',
#                                                     'first_frame_320': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=0&type=39&tkn=7WP6TVLi-_pCbdedCvOHmBCL-WU&fn=vid_md',
#                                                     'first_frame_800': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=0&type=39&tkn=7WP6TVLi-_pCbdedCvOHmBCL-WU&fn=vid_f',
#                                                     'height': 1080,
#                                                     'id': 456242298,
#                                                     'local_views': 608826,
#                                                     'owner_id': -22822305,
#                                                     'photo_1280': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=15&type=39&tkn=jDNWGXNLxWliqGtQPAmPZJmGSUk&fn=vid_w',
#                                                     'photo_130': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=15&type=39&tkn=jDNWGXNLxWliqGtQPAmPZJmGSUk&fn=vid_s',
#                                                     'photo_320': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=15&type=39&tkn=jDNWGXNLxWliqGtQPAmPZJmGSUk&fn=vid_l',
#                                                     'photo_800': 'https://i.mycdn.me/getVideoPreview?id=4132972923511&idx=15&type=39&tkn=jDNWGXNLxWliqGtQPAmPZJmGSUk&fn=vid_x',
#                                                     'response_type': 'full',
#                                                     'title': 'VK Клипы: '
#                                                              'конструктор '
#                                                              'впечатлений',
#                                                     'track_code': 'video_ed29501epyW0fVpFtJtiqGiWnTCYAwGw_jCIq60dLu9_iA9o6MqWBKp_XSK3nWGpZfuRBa4xNYLMCbCv2nxCg3-ZIlra8qQ2mQ',
#                                                     'views': 608826,
#                                                     'width': 1080}}],
#                          'comments': {'can_post': 1,
#                                       'count': 331,
#                                       'groups_can_post': True},
#                          'date': 1681488780,
#                          'from_id': -22822305,
#                          'hash': 'AX2f037q9I8-ZsfTqg',
#                          'id': 1401828,
#                          'inner_type': 'wall_wallpost',
#                          'likes': {'can_like': 1,
#                                    'can_publish': 1,
#                                    'count': 4280,
#                                    'repost_disabled': False,
#                                    'user_likes': 0},
#                          'marked_as_ads': 0,
#                          'owner_id': -22822305,
#                          'post_source': {'type': 'vk'},
#                          'post_type': 'post',
#                          'reposts': {'count': 5581, 'user_reposted': 0},
#                          'text': 'Смотрите в VK Клипах то, что подходит под '
#                                  'ваши предпочтения и текущее настроение, — '
#                                  'уникальный конструктор впечатлений '
#                                  'моментально изменит вашу ленту '
#                                  'рекомендаций. \n'
#                                  '\n'
#                                  'Он находится в правом верхнем углу вкладки '
#                                  '«Для вас». Внутри есть три раздела: «Что '
#                                  'хочется», «Какое настроение» и «Какие авторы '
#                                  'интересны». А ещё — возможность ограничить '
#                                  'взрослый контент, если смотрите клипы с '
#                                  'детьми. Все настройки применятся на час, '
#                                  'после чего лента вернётся к стандартным '
#                                  'рекомендациям. \n'
#                                  '\n'
#                                  'Чем чаще вы пользуетесь конструктором '
#                                  'впечатлений, тем лучше алгоритмы понимают '
#                                  'ваши предпочтения. А значит, в ленте вы '
#                                  'будете видеть ещё больше интересных вам '
#                                  'клипов. \n'
#                                  '\n'
#                                  'В течение недели новая функция появится у '
#                                  'всех пользователей. А у кого-то уже сейчас. '
#                                  'Обновляйтесь и проверяйте!',
#                          'type': 'post',
#                          'views': {'count': 623656}}]}}

# %% [markdown]
# Посмотрим на количество результатов:

# %%
len(response.json()['response']['items'])
## 100
# Out:
# 100

# %% [markdown]
# Посмотрим на информацию об отдельном сообщении:

# %%
response.json()['response']['items'][0]
# Out:
# {'inner_type': 'wall_wallpost',
#  'comments': {'can_post': 1, 'count': 65, 'groups_can_post': True},
#  'marked_as_ads': 0,
#  'hash': 'acq7bmTkX76qGV9p9A',
#  'type': 'post',
#  'attachments': [],
#  'date': 1708344300,
#  'from_id': -22822305,
#  'id': 1461279,
#  'likes': {'can_like': 1,
#   'count': 94,
#   'user_likes': 0,
#   'can_publish': 1,
#   'repost_disabled': False},
#  'owner_id': -22822305,
#  'post_source': {'type': 'vk'},
#  'post_type': 'post',
#  'reposts': {'count': 9, 'user_reposted': 0},
#  'text': 'А похвастайтесь своими результатами в «Шагах»!\n\nС телефона заходим [https://vk.com/app7539087_9849589|сюда], делаем скриншот, скидываем в комментарии 👇',
#  'views': {'count': 32180}}

# %% [markdown]
# В полях comments, likes и reposts содержится статистика по взаимодействию с сообщением пользователей (на момент получения информации) — число комментариев, лайков и репостов.

# %% [markdown]
# Давайте соберём итоговую статистику для последних десяти непустых сообщений в словарь stats. В качестве ключа будем использовать начало сообщения (если начало сообщения пустое, то информацию о таком сообщении проигнорируем), в качестве значения — список с тремя интересующими нас метриками и временем публикации (комментарии, лайки, репосты, дата публикации):

# %%
stats = {} 
count_post = 0 # Счётчик «непустых» сообщений
for record in response.json()['response']['items'][:]:
    title = record['text'][:30] 
    if title: 
        stats[title] = [record['comments']['count'], record['likes']['count'], record['reposts']['count'], record['date']] 
        count_post += 1 
    if count_post < 10: 
        continue 
    else: 
        break 
pprint(stats)
# Out:
# {'[https://vk.com/fest_ufa|Уфа],': [124, 740, 224, 1706860913],
#  'А похвастайтесь своими результ': [65, 94, 9, 1708344300],
#  'В такие моменты важно говорить': [264, 3421, 390, 1707300472],
#  'ВКонтакте обновились истории. ': [325, 961, 266, 1706598480],
#  'ВКонтакте появился [vk.com/saf': [349, 351, 70, 1707996601],
#  'Всех с Днём влюблённых! 💙\n\nНад': [244, 412, 39, 1707908176],
#  'Как понять, кто удалил вас из ': [440, 1006, 412, 1706275200],
#  'Как сделать отличную аватарку ': [370, 1156, 101, 1707490737],
#  'Какие персонажи — такие и чёрн': [333, 839, 115, 1706950860],
#  'Скидывайте в комментарии ваше ': [1002, 872, 166, 1707136200]}
